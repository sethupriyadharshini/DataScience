# %%
import pandas as pd

# %%
dataset = pd.read_csv("kidney_disease.csv")

# %%
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
from Univariate import Univariate

# %%
qual,quan=Univariate.qualQuan(dataset)

# %%
qual
# Out:
# ['rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'pcv',
#  'wc',
#  'rc',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
quan
# Out:
# ['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']

# %%
dataset[quan].isna().sum()
# Out:
# id       0
# age      9
# bp      12
# sg      47
# al      46
# su      49
# bgr     44
# bu      19
# sc      17
# sod     87
# pot     88
# hemo    52
# dtype: int64

# %%
dataset[qual].isna().sum()
# Out:
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
for columnName in qual:
    mode_data=dataset[columnName].mode()[0]
    dataset.fillna({columnName:mode_data},inplace=True)

# %%
dataset[qual].isna().sum()
# Out:
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
for columnName in quan:
    mean_data=dataset[columnName].mean()
    dataset.fillna({columnName:mean_data},inplace=True) #inplace=True -> fill the mean_data into NA cell in same dataset directly

# %%
dataset[quan].isna().sum()
# Out:
# id      0
# age     0
# bp      0
# sg      0
# al      0
# su      0
# bgr     0
# bu      0
# sc      0
# sod     0
# pot     0
# hemo    0
# dtype: int64

# %%
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
dataset.to_csv("CKD_Using_For_Loop.csv",index=False)

# %% [markdown]
# # USING SIMPLE IMPUTER

# %%
datasetImputer = pd.read_csv("kidney_disease.csv")

# %%
datasetImputer
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
datasetImputer.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
qualImputer,quanImputer=Univariate.qualQuan(datasetImputer)

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(datasetImputer[quanImputer])
da_quan=imp.transform(datasetImputer[quanImputer])

quan_dataset=pd.DataFrame(da_quan,columns=quanImputer)

quan_dataset
# Out:
#         id   age    bp     sg   al   su         bgr    bu   sc         sod  \
# 0      0.0  48.0  80.0  1.020  1.0  0.0  121.000000  36.0  1.2  137.528754
# 1      1.0   7.0  50.0  1.020  4.0  0.0  148.036517  18.0  0.8  137.528754
# 2      2.0  62.0  80.0  1.010  2.0  3.0  423.000000  53.0  1.8  137.528754
# 3      3.0  48.0  70.0  1.005  4.0  0.0  117.000000  56.0  3.8  111.000000
# 4      4.0  51.0  80.0  1.010  2.0  0.0  106.000000  26.0  1.4  137.528754
# ..     ...   ...   ...    ...  ...  ...         ...   ...  ...         ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  140.000000  49.0  0.5  150.000000
# 396  396.0  42.0  70.0  1.025  0.0  0.0   75.000000  31.0  1.2  141.000000
# 397  397.0  12.0  80.0  1.020  0.0  0.0  100.000000  26.0  0.6  137.000000
# 398  398.0  17.0  60.0  1.025  0.0  0.0  114.000000  50.0  1.0  135.000000
# 399  399.0  58.0  80.0  1.025  0.0  0.0  131.000000  18.0  1.1  141.000000
#
#           pot  hemo
# 0    4.627244  15.4
# 1    4.627244  11.3
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp.fit(datasetImputer[qualImputer])
da_qual=imp.transform(datasetImputer[qualImputer])

qual_dataset=pd.DataFrame(da_qual,columns=qualImputer)

qual_dataset
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0    normal    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1    normal    normal  notpresent  notpresent  38  6000  5.2   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  5.2   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
combined_Dataset=pd.concat([quan_dataset,qual_dataset],axis=1)

# %%
combined_Dataset
# Out:
#         id   age    bp     sg   al   su         bgr    bu   sc         sod  \
# 0      0.0  48.0  80.0  1.020  1.0  0.0  121.000000  36.0  1.2  137.528754
# 1      1.0   7.0  50.0  1.020  4.0  0.0  148.036517  18.0  0.8  137.528754
# 2      2.0  62.0  80.0  1.010  2.0  3.0  423.000000  53.0  1.8  137.528754
# 3      3.0  48.0  70.0  1.005  4.0  0.0  117.000000  56.0  3.8  111.000000
# 4      4.0  51.0  80.0  1.010  2.0  0.0  106.000000  26.0  1.4  137.528754
# ..     ...   ...   ...    ...  ...  ...         ...   ...  ...         ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  140.000000  49.0  0.5  150.000000
# 396  396.0  42.0  70.0  1.025  0.0  0.0   75.000000  31.0  1.2  141.000000
# 397  397.0  12.0  80.0  1.020  0.0  0.0  100.000000  26.0  0.6  137.000000
# 398  398.0  17.0  60.0  1.025  0.0  0.0  114.000000  50.0  1.0  135.000000
# 399  399.0  58.0  80.0  1.025  0.0  0.0  131.000000  18.0  1.1  141.000000
#
# ...

# %%
combined_Dataset.to_csv("CKD_Using_Imputer.csv",index=False) #- index=False → prevents pandas from writing the row index as an extra column in the CSV.

# %%
combined_Dataset.isna().sum()
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64
